# %% [markdown]
# # 作業
# ### 用 digits (3個數字即可 , dataset.load_digits(n_class=3)) 資料嘗試跑 PCA

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

from sklearn import decomposition
from sklearn import datasets

digits = datasets.load_digits(n_class=3)
x = digits.data
y = digits.target

# %% [markdown]
# 載入 相關套件 並 執行 PCA 實驗 ...

# %%
for i,digit in enumerate(x[:3]):
    digit = digit.reshape(8,8)
    plt.imshow(digit, cmap = plt.cm.binary)
    plt.title(str(i))
    plt.show()

# %%
print(x.shape)
print(y.shape)
# Out:
# (537, 64)
# (537,)

# %%
pca = decomposition.PCA(n_components = 3)
pca.fit(x)
x = pca.transform(x)
x.shape
# Out:
# (537, 3)

# %%
fig = plt.figure(1, figsize = (8,6))
ax = Axes3D(fig, rect = [0,0,0.95,1], elev = 48,azim = 134)

for name, label in [('1', 1), ('2',2), ('3',3)]:
    ax.text3D(  x[y == label, 0].mean(),
                    x[y == label, 1].mean() + 1.5,
                    x[y == label, 2].mean(), name, horizontalalignment = 'center',
                    bbox = dict(alpha = 0.5, edgecolor = 'w', facecolor = 'w'))

y = np.choose(y,[1,2,0]).astype(float)
plt.scatter(x[:,0], x[:,1], x[:,2], c = y, cmap = plt.cm.nipy_spectral, edgecolor = 'k')

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])

plt.show()
# Out:
# /Users/i-an/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: Mean of empty slice.
#   """
# /Users/i-an/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/i-an/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: Mean of empty slice.
#
# /Users/i-an/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: Mean of empty slice.
#   import sys
# /Users/i-an/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py:874: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# /Users/i-an/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:32: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial)
# /Users/i-an/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:28: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial)
# posx and posy should be finite values
# posx and posy should be finite values
