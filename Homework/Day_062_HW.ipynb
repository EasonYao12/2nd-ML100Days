# %% [markdown]
# # t-sne 觀察 : 流形還原

# %% [markdown]
# # [作業目標]
# - 試著模仿範例寫法, 觀察 S 形使用 t-SNE , 在不同困惑度 (perplexity) 下的流形還原效果

# %% [markdown]
# # [作業重點]
# - 使用 S 形資料集, 觀察 t-sne 在困惑度 (perplexity) 有所不同時, 流形還原的效果如何變化 (In[4], Out[4])
# - Hint : ax.scatter(Y[red, 0], Y[red, 1], c="r") 與 ax.scatter(Y[green, 0], Y[green, 1], c="g") 兩行改一行 ax.scatter(Y[:, 0], Y[:, 1], c=color)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
from sklearn import datasets, manifold
from time import time

# %%
n_samples = 300
n_components = 2
perplexities = [4, 6, 9, 14, 21, 30, 45, 66, 100]

x, y = datasets.make_circles(n_samples = n_samples, factor = 0.5, noise = 0.05)
red = (y == 0)
green = (y == 1)

# %%
(fig, subplots) = plt.subplots(2,5, figsize = (15,6) )
ax = subplots[0][0]
ax.set_title('Original')
ax.scatter(x[red,0], x[red,1] , c = 'r')
ax.scatter(x[green, 0], x[green, 1], c = 'g')
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())
plt.axis('tight')

for i, perplexity in enumerate(perplexities):
    if i < 4:
        ax = subplots[0][i+1]
    else :
        ax = subplots[1][i-4]
    
    t0 = time()
    tsne = manifold.TSNE(n_components = n_components, init = 'random', random_state = 0, perplexity = perplexity)
    x_tsne = tsne.fit_transform(x)
    t1 = time()
    
    print(f' Circles, preplexity : {perplexity} in {t1-t0} sec')
    ax.set_title(f'Preplexity : {perplexity}')
    ax.scatter(x_tsne[red, 0], x_tsne[red, 1], c = 'r')
    ax.scatter(x_tsne[green, 0], x_tsne[green, 1], c = 'g')
    ax.xaxis.set_major_formatter(NullFormatter())
    ax.yaxis.set_major_formatter(NullFormatter())
    ax.axis('tight')
plt.show()
# Out:
#  Circles, preplexity : 4 in 1.0122458934783936 sec
#  Circles, preplexity : 6 in 0.9960629940032959 sec
#  Circles, preplexity : 9 in 1.0464859008789062 sec
#  Circles, preplexity : 14 in 1.0368120670318604 sec
#  Circles, preplexity : 21 in 1.1554973125457764 sec
#  Circles, preplexity : 30 in 1.233982801437378 sec
#  Circles, preplexity : 45 in 1.0974571704864502 sec
#  Circles, preplexity : 66 in 1.5748438835144043 sec
#  Circles, preplexity : 100 in 1.7821760177612305 sec

# %% [markdown]
# # 作業
# * 將原始資料集換為S型圖, 觀察不同 perplexity 下的流形還原結果

# %%
# 繪製不同 perplexity 下的 t-SNE 流形還原圖 (請注意! 語法也要對應調整)
x, color = datasets.samples_generator.make_s_curve(n_samples = n_samples, random_state = 0)

# %%
print(f' data shape : {x.shape}')
print(f' color shape : {color.shape}')
# Out:
#  data shape : (300, 3)
#  color shape : (300,)

# %%
(fig, subplots) = plt.subplots(2, 5, figsize = (15,6))

ax = subplots[0][0]
ax.set_title('Original')
ax.scatter(x[:, 0], x[:,2], c = color)
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())
plt.axis('tight')

for i, perplexity in enumerate(perplexities):
    if i < 4 :
        ax = subplots[0][i+1]
    else:
        ax = subplots[1][i-4]
    
    t0 = time()
    tsne = manifold.TSNE(n_components = n_components, init = 'pca', random_state = 0, perplexity = perplexity)
    x_tsne = tsne.fit_transform(x)
    t1 = time()
    print(f'Circles, perplexity = {perplexity}, {t1-t0} sec')
    ax.set_title(f'perplexity : {perplexity}')
    ax.scatter(x_tsne[:,0], x_tsne[:,1], c = color)
    ax.xaxis.set_major_formatter(NullFormatter())
    ax.yaxis.set_major_formatter(NullFormatter())
    ax.axis('tight')

plt.show()
# Out:
# Circles, perplexity = 4, 1.1972768306732178 sec
# Circles, perplexity = 6, 1.0513341426849365 sec
# Circles, perplexity = 9, 1.1266369819641113 sec
# Circles, perplexity = 14, 1.2823400497436523 sec
# Circles, perplexity = 21, 1.2001893520355225 sec
# Circles, perplexity = 30, 1.3158209323883057 sec
# Circles, perplexity = 45, 1.147000789642334 sec
# Circles, perplexity = 66, 1.1756720542907715 sec
# Circles, perplexity = 100, 1.9303011894226074 sec

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize = (6,4))
ax = Axes3D(fig, rect = [0,0,0.95,1], elev = 48, azim = 134)
ax.scatter(x[:,2], x[:,1], x[:,0], c = color ,edgecolor = 'k')
ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
ax.set_title('Original S curve data')
ax.dist = 12
